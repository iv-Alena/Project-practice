# %% [markdown]
# <a href="https://colab.research.google.com/github/iv-Alena/Project-practice/blob/main/%D0%98%D0%B2%D0%B0%D0%BD%D0%BE%D0%B2%D0%B0_%D0%90%D0%95_%D0%9F%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%BD%D0%B0%D1%8F_%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Необходимые импорты и установки библиотек:

# %%
# pip install inference-sdk

# %%
# ! pip -q install roboflow

# %%
from inference_sdk import InferenceHTTPClient
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# %% [markdown]
# Предобученная модель и функция для вывода изображения:

# %%
# предобученная модель
CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="VDdoyat8yYSu3wKgBWPA"
)

# %%
# функция вывода изображения
def print_pic(sample, result):
  img_path = sample
  img = Image.open(img_path).convert("RGB")
  draw = ImageDraw.Draw(img)
  preds = result.get("predictions", [])
  # координаты
  for p in preds:
      x, y = p["x"], p["y"]
      w, h = p["width"], p["height"]
      x0 = x - w / 2
      y0 = y - h / 2
      x1 = x + w / 2
      y1 = y + h / 2
      # Рамка
      draw.rectangle([x0, y0, x1, y1], outline="red", width=3)
  # вывод
  plt.figure(figsize=(4, 4))
  plt.imshow(img)
  plt.axis("off")
  plt.show()

# %% [markdown]
# Тестирование модели на данных из открытых источников:

# %%
result1 = CLIENT.infer('sample1.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result1['predictions'][0]['class']}, с вероятностью {result1['predictions'][0]['confidence']:.2f}')
print_pic('sample1.jpg', result1)
# Out:
# Класс распознанной пицы: American Robin, с вероятностью 0.71

# %%
result2 = CLIENT.infer('sample2.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result2['predictions'][0]['class']}, с вероятностью {result2['predictions'][0]['confidence']:.2f}')
print_pic('sample2.jpg', result2)
# Out:
# Класс распознанной пицы: American Robin, с вероятностью 0.70

# %%
result3 = CLIENT.infer('sample3.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result3['predictions'][0]['class']}, с вероятностью {result3['predictions'][0]['confidence']:.2f}')
print_pic('sample3.jpg', result3)
# Out:
# Класс распознанной пицы: Chipmunk, с вероятностью 0.49

# %%
result4 = CLIENT.infer('sample4.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result4['predictions'][0]['class']}, с вероятностью {result4['predictions'][0]['confidence']:.2f}')
print_pic('sample4.jpg', result4)
# Out:
# Класс распознанной пицы: Eastern_Blue_Bird, с вероятностью 0.83

# %%
result5 = CLIENT.infer('sample5.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result5['predictions'][0]['class']}, с вероятностью {result5['predictions'][0]['confidence']:.2f}')
print_pic('sample5.jpg', result5)
# Out:
# Класс распознанной пицы: Gray_Catbord, с вероятностью 0.44

# %% [markdown]
# Неверно определен класс в результате 5. Верный: Dark_eyed_Junco

# %%
result6 = CLIENT.infer('sample6.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result6['predictions'][0]['class']}, с вероятностью {result6['predictions'][0]['confidence']:.2f}')
print_pic('sample6.jpg', result6)
# Out:
# Класс распознанной пицы: Gray_Catbord, с вероятностью 0.82

# %% [markdown]
# Неверно определен класс в результате 6. Верный: Dark_eyed_Junco

# %%
result7 = CLIENT.infer('sample7.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result7['predictions'][0]['class']}, с вероятностью {result7['predictions'][0]['confidence']:.2f}')
print(f'Класс распознанной пицы: {result7['predictions'][1]['class']}, с вероятностью {result7['predictions'][1]['confidence']:.2f}')
print_pic('sample7.jpg', result7)
# Out:
# Класс распознанной пицы: Dark_eyed_Junco, с вероятностью 0.90
# Класс распознанной пицы: American Robin, с вероятностью 0.48

# %% [markdown]
# В результате 7 верно: Dark_eyed_Junco

# %%
result8 = CLIENT.infer('sample8.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result8['predictions'][0]['class']}, с вероятностью {result8['predictions'][0]['confidence']:.2f}')
print_pic('sample8.jpg', result8)
# Out:
# Класс распознанной пицы: Downy_Woodpecker, с вероятностью 0.68

# %%
result9 = CLIENT.infer('sample9.jpg', model_id="ne-bird/7")
print(f'Класс распознанной пицы: {result9['predictions'][0]['class']}, с вероятностью {result9['predictions'][0]['confidence']:.2f}')
print_pic('sample9.jpg', result9)
# Out:
# Класс распознанной пицы: Gray_Catbord, с вероятностью 0.68
